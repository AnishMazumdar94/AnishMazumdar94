# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\\data analytics\\csv and exl files\\netflix1.csv")
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
df.shape
# Out:
# (8790, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %% [markdown]
# ##### MOVIES IN NETFLIX

# %%
df.loc[(df["type"]=="Movie"),["type","title","director","release_year","duration"]].sort_values(by="release_year")
# Out:
#        type                                          title  \
# 5698  Movie                                 Prelude to War
# 6037  Movie                           The Battle of Midway
# 6422  Movie  Undercover: How to Operate Behind Enemy Lines
# 6491  Movie             Why We Fight: The Battle of Russia
# 6510  Movie                WWII: Report from the Aleutians
# ...     ...                                            ...
# 1214  Movie                      Brian Regan: On the Rocks
# 778   Movie                                   The Ice Road
# 780   Movie                                The Seventh Day
# 1222  Movie                                   I Care a Lot
# 6365  Movie                              99 Songs (Telugu)
#
#                          director  release_year duration
# 5698                  Frank Capra          1942   52 min
# 6037                    John Ford          1942   18 min
# 6422                    John Ford          1943   61 min
# ...

# %% [markdown]
# ##### TV SHOW IN NETFLIX

# %%
df.loc[(df["type"]=="TV Show"),["type","title","director","release_year","duration"]].sort_values(by="release_year")
# Out:
#          type                                title  \
# 421   TV Show    Pioneers: First Women Filmmakers*
# 6874  TV Show  Five Came Back: The Reference Films
# 5679  TV Show  Pioneers of African-American Cinema
# 8746  TV Show  The Twilight Zone (Original Series)
# 8697  TV Show               The Andy Griffith Show
# ...       ...                                  ...
# 6700  TV Show                         Young Royals
# 6702  TV Show                               Somos.
# 6704  TV Show                             StarBeam
# 6706  TV Show                             Sex/Life
# 1     TV Show                            Ganglands
#
#                                                director  release_year  \
# 421                                           Not Given          1925
# 6874                                          Not Given          1945
# 5679  Oscar Micheaux, Spencer Williams, Richard E. N...          1946
# ...

# %%
df["type"].value_counts()
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
df["type"].value_counts().plot(x="Movie",y="TV Show",kind="pie",autopct="%1.2f%%",title="NETFLIX SHOW DISTRIBUTION")
# Out:
# <Axes: title={'center': 'NETFLIX SHOW DISTRIBUTION'}, ylabel='count'>

# %% [markdown]
# ##### TOP 3 COUNTRY WHERE NETFLIX TV SHOW AND MOVIES HAS RELEASED MOST

# %%
df["country"].value_counts().head(3)
# Out:
# country
# United States     3240
# India             1057
# United Kingdom     638
# Name: count, dtype: int64

# %%
df["country"].value_counts().head(3).plot(x="country",y="counts",kind="bar",color="green")
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# ##### TOP 10 RATING OF GENRE IN NETFLIX

# %%
df["rating"].value_counts().head(10)
# Out:
# rating
# TV-MA    3205
# TV-14    2157
# TV-PG     861
# R         799
# PG-13     490
# TV-Y7     333
# TV-Y      306
# PG        287
# TV-G      220
# NR         79
# Name: count, dtype: int64

# %%
df["rating"].value_counts().head(10).plot(x="rating",y="counts",kind="pie",autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ##### TOP 5 CETAGORIES OF TV SHOW AND MOVIES IN NETFLIX

# %%
df["listed_in"].value_counts().head()
# Out:
# listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Name: count, dtype: int64

# %%
df["listed_in"].value_counts().head().plot(x="listed_in",y="counts",kind="bar")
# Out:
# <Axes: xlabel='listed_in'>

# %% [markdown]
# #### TOP 10 MOST MOVIE AND TV SHOW RELEASED YEAR IN NETFLIX

# %%
df["release_year"].value_counts().head(10)
# Out:
# release_year
# 2018    1146
# 2017    1030
# 2019    1030
# 2020     953
# 2016     901
# 2021     592
# 2015     555
# 2014     352
# 2013     286
# 2012     236
# Name: count, dtype: int64

# %%
df["release_year"].value_counts().head(10).plot(x="release_year",y="counts",kind="bar")
# Out:
# <Axes: xlabel='release_year'>

# %% [markdown]
# ##### TOP 5 RECENTLY RELEASED GENRE IN NETFLIX

# %%
df.sort_values(by="release_year",ascending=False).head()
# Out:
#      show_id     type                           title         director  \
# 6871   s1318  TV Show                    Nadiya Bakes        Not Given
# 541     s394    Movie       A Second Chance:  Rivals!        Clay Glen
# 531     s376    Movie                  Resort to Love  Steven Tsuchida
# 532     s373    Movie  Rurouni Kenshin: The Beginning     Keishi Otomo
# 533     s388    Movie                            Mimi    Laxman Utekar
#
#              country date_added  release_year rating  duration  \
# 6871  United Kingdom  2/12/2021          2021   TV-G  1 Season
# 541        Australia  7/23/2021          2021     PG    91 min
# 531        Not Given  7/29/2021          2021  TV-14   102 min
# 532        Not Given  7/30/2021          2021  TV-MA   138 min
# 533            India  7/27/2021          2021  TV-14   132 min
#
#                                               listed_in
# 6871  British TV Shows, International TV Shows, Real...
# ...

# %% [markdown]
# ##### TOP 5 OLDEST GENRE RELEASED IN NETFLIX

# %%
df.sort_values(by="release_year").head()
# Out:
#      show_id     type                                          title  \
# 421    s4251  TV Show              Pioneers: First Women Filmmakers*
# 5698   s7791    Movie                                 Prelude to War
# 6037   s8206    Movie                           The Battle of Midway
# 6510   s8764    Movie                WWII: Report from the Aleutians
# 6422   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
#
#          director        country  date_added  release_year rating  duration  \
# 421     Not Given       Pakistan  12/30/2018          1925  TV-14  1 Season
# 5698  Frank Capra  United States   3/31/2017          1942  TV-14    52 min
# 6037    John Ford  United States   3/31/2017          1942  TV-14    18 min
# 6510  John Huston  United States   3/31/2017          1943  TV-PG    45 min
# 6422    John Ford  United States   3/31/2017          1943  TV-PG    61 min
#
#                           listed_in
# 421                        TV Shows
# ...

# %% [markdown]
# ##### TOP 10 NEWLY RELEASED GENRE IN NETFLIX IN INDIA

# %%
df.loc[(df["country"]=="India"),["title","type","director","country","release_year","duration","rating",'listed_in']].sort_values(by="release_year",ascending=False).head(10)
# Out:
#                                    title     type  \
# 952                            Milestone    Movie
# 6572                        Kota Factory  TV Show
# 409                             Navarasa  TV Show
# 533                                 Mimi    Movie
# 1030                Searching For Sheela    Movie
# 6908  Mighty Little Bheem: Kite Festival  TV Show
# 6846                       Bombay Begums  TV Show
# 6815                         The Big Day  TV Show
# 6776                      Lava Ka Dhaava  TV Show
# 6753                        Alma Matters  TV Show
#
#                                                director country  release_year  \
# 952                                            Ivan Ayr   India          2021
# 6572                                          Not Given   India          2021
# 409   Bejoy Nambiar, Priyadarshan, Karthik Narain, V...   India          2021
# 533                                       Laxman Utekar   India          2021
# ...

# %% [markdown]
# ##### TOP 5 DIRECTOR OF NETFLIX

# %%
df["director"].value_counts().head()
# Out:
# director
# Not Given                 2588
# Rajiv Chilaka               20
# Alastair Fothergill         18
# Raúl Campos, Jan Suter      18
# Suhas Kadav                 16
# Name: count, dtype: int64

# %% [markdown]
# ##### COUNTRY WISE RECENTLY RELEASED GENRE

# %%
df.loc[df.groupby("country")["release_year"].idxmax().values,["title","director","country","release_year","duration","rating","listed_in"]].reset_index()
# Out:
#     index                      title  \
# 0     906      Soy Rada: Serendipity
# 1     541  A Second Chance:  Rivals!
# 2     938          The Strange House
# 3    2438     Sincerely Yours, Dhaka
# 4    7173              Sunny Bunnies
# ..    ...                        ...
# 81   6816              Magical Andes
# 82   4832                     El Che
# 83    835           Camellia Sisters
# 84   4020          Hitler - A Career
# 85   1988                   Cook Off
#
#                                              director       country  \
# 0                                          Pablo Faro     Argentina
# 1                                           Clay Glen     Australia
# 2                                    Daniel Prochaska       Austria
# 3   Nuhash Humayun, Syed Ahmed Shawki, Rahat Rahma...    Bangladesh
# 4                                           Not Given       Belarus
# ..                                                ...           ...
# ...
